# %% [markdown]
# # Import Libraries

# %%
from tqdm import tqdm
from topicutils import get_topics_lda, sample_polarity
import pandas as pd
import os
tqdm.pandas()

# Allow multiple outputs to be displayed for each cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

DATASET_DIR = '../dataset/'

# %% [markdown]
# # Load Dataset

# %%
london = pd.read_csv(os.path.join(DATASET_DIR, 'london_preprocessed.csv'))
nyc = pd.read_csv(os.path.join(DATASET_DIR, 'nyc_preprocessed.csv'))

# Drop rows with missing values
london = london.dropna()
nyc = nyc.dropna()

data = pd.concat([london, nyc], axis=0)

# %%
sample_size = 10000
sample_london = london.sample(sample_size)
sample_nyc = nyc.sample(sample_size)
sample_positives = sample_polarity(data, 1.0, sample_size)
sample_negatives = sample_polarity(data, 0.0, sample_size)
sample_london_positives = sample_polarity(london, 1.0, sample_size)
sample_london_negatives = sample_polarity(london, 0.0, sample_size)
sample_nyc_positives = sample_polarity(nyc, 1.0, sample_size)
sample_nyc_negatives = sample_polarity(nyc, 0.0, sample_size)

# %% [markdown]
# # Run LDA

# %%
num_topics = 5
lda_london, vect_london = get_topics_lda(sample_london, num_topics, 'London')
lda_nyc, vect_nyc = get_topics_lda(sample_nyc, num_topics, 'NYC')
lda_positives, vect_positives = get_topics_lda(sample_positives, num_topics, 'Positive Reviews')
lda_negatives, vect_negatives = get_topics_lda(sample_negatives, num_topics, 'Negative Reviews')
lda_london_positives, vect_london_positives = get_topics_lda(sample_london_positives, num_topics, 'London Positive Reviews')
lda_london_negatives, vect_london_negatives = get_topics_lda(sample_london_negatives, num_topics, 'London Negative Reviews')
lda_nyc_positives, vect_nyc_positives = get_topics_lda(sample_nyc_positives, num_topics, 'NYC Positive Reviews')
lda_nyc_negatives, vect_nyc_negatives = get_topics_lda(sample_nyc_negatives, num_topics, 'NYC Negative Reviews')
# Out:
# Topics for London
# 	Topic 0:
# ['host', 'needed', 'pleasant', 'nice', 'london', 'place', 'location', 'great', 'stay', 'perfect']
#
# 	Topic 1:
# ['location', 'perfect', 'loved', 'room', 'clean', 'host', 'great', 'stay', 'place', 'nice']
#
# 	Topic 2:
# ['comfortable', 'host', 'nice', 'apartment', 'perfect', 'location', 'place', 'london', 'great', 'stay']
#
# 	Topic 3:
# ['close', 'host', 'clean', 'location', 'room', 'lovely', 'stay', 'great', 'place', 'nice']
#
# 	Topic 4:
# ['good', 'excellent', 'lovely', 'clean', 'nice', 'host', 'location', 'place', 'stay', 'great']
#
# Topics for NYC
# 	Topic 0:
# ['house', 'apartment', 'comfortable', 'home', 'host', 'clean', 'great', 'nice', 'stay', 'place']
#
# 	Topic 1:
# ['location', 'close', 'subway', 'apartment', 'nice', 'clean', 'stay', 'place', 'great', 'easy']
#
# 	Topic 2:
# ['comfortable', 'amazing', 'perfect', 'clean', 'nice', 'host', 'location', 'stay', 'place', 'great']
#
# 	Topic 3:
# ['host', 'perfect', 'nice', 'clean', 'apartment', 'stay', 'location', 'described', 'place', 'great']
#
# 	Topic 4:
# ['location', 'room', 'wonderful', 'host', 'comfortable', 'stay', 'clean', 'great', 'place', 'nice']
#
# Topics for Positive Reviews
# 	Topic 0:
# ['apartment', 'good', 'lovely', 'clean', 'host', 'nice', 'location', 'stay', 'place', 'great']
#
# 	Topic 1:
# ['subway', 'location', 'apartment', 'station', 'easy', 'stay', 'nice', 'great', 'place', 'close']
#
# 	Topic 2:
# ['comfortable', 'hospitality', 'place', 'host', 'stay', 'space', 'location', 'great', 'wonderful', 'perfect']
#
# 	Topic 3:
# ['perfect', 'location', 'book', 'place', 'tidy', 'great', 'clean', 'stay', 'nice', 'thank']
#
# 	Topic 4:
# ['location', 'house', 'beautiful', 'nice', 'clean', 'great', 'place', 'recommend', 'stay', 'host']
#
# Topics for Negative Reviews
# 	Topic 0:
# ['far', 'cozy', 'sorry', 'unfortunately', 'location', 'walking', 'apartment', 'difficult', 'stay', 'place']
#
# 	Topic 1:
# ['hot', 'host', 'shower', 'bathroom', 'water', 'place', 'worst', 'room', 'dirty', 'cold']
#
# 	Topic 2:
# ['place', 'stay', 'host', 'nice', 'uncomfortable', 'bad', 'room', 'bed', 'terrible', 'horrible']
#
# 	Topic 3:
# ['clean', 'recommend', 'wall', 'host', 'uncomfortable', 'apartment', 'stay', 'dirty', 'place', 'room']
#
# 	Topic 4:
# ['helpful', 'convenient', 'london', 'disappointed', 'home', 'stay', 'base', 'extremely', 'place', 'cozy']
#
# Topics for London Positive Reviews
# 	Topic 0:
# ['money', 'nice', 'host', 'london', 'stay', 'location', 'place', 'value', 'great', 'perfect']
#
# 	Topic 1:
# ['apartment', 'communication', 'wonderful', 'nice', 'lovely', 'host', 'location', 'stay', 'place', 'great']
#
# 	Topic 2:
# ['home', 'highly', 'recommend', 'lovely', 'great', 'place', 'thank', 'amazing', 'host', 'stay']
#
# 	Topic 3:
# ['stay', 'place', 'comfortable', 'room', 'host', 'great', 'location', 'good', 'clean', 'nice']
#
# 	Topic 4:
# ['stay', 'walk', 'location', 'easy', 'nice', 'tube', 'place', 'great', 'station', 'close']
#
# Topics for London Negative Reviews
# 	Topic 0:
# ['stay', 'wifi', 'place', 'experience', 'worst', 'terrible', 'host', 'responsive', 'helpful', 'extremely']
#
# 	Topic 1:
# ['airbnb', 'stay', 'host', 'didnt', 'cold', 'shower', 'dirty', 'room', 'hot', 'water']
#
# 	Topic 2:
# ['bit', 'stay', 'uncomfortable', 'bed', 'cozy', 'disappointed', 'dirty', 'cold', 'place', 'room']
#
# 	Topic 3:
# ['host', 'good', 'great', 'convenient', 'home', 'stay', 'place', 'london', 'base', 'cozy']
#
# 	Topic 4:
# ['time', 'extremely', 'issue', 'place', 'comfortable', 'host', 'accommodating', 'located', 'location', 'spacious']
#
# Topics for NYC Positive Reviews
# 	Topic 0:
# ['good', 'location', 'nice', 'spot', 'wonderful', 'host', 'stay', 'place', 'thank', 'great']
#
# 	Topic 1:
# ['clean', 'location', 'apartment', 'close', 'subway', 'nice', 'easy', 'stay', 'place', 'great']
#
# 	Topic 2:
# ['room', 'home', 'great', 'comfortable', 'host', 'clean', 'stay', 'place', 'nice', 'loved']
#
# 	Topic 3:
# ['apartment', 'room', 'service', 'hotel', 'place', 'location', 'nice', 'space', 'clean', 'great']
#
# 	Topic 4:
# ['comfortable', 'amazing', 'perfect', 'clean', 'nice', 'host', 'location', 'stay', 'place', 'great']
#
# Topics for NYC Negative Reviews
# 	Topic 0:
# ['hotel', 'street', 'place', 'worst', 'night', 'terrible', 'difficult', 'room', 'cold', 'parking']
#
# 	Topic 1:
# ['inside', 'dirty', 'filthy', 'smell', 'sheet', 'dangerous', 'studio', 'clean', 'careful', 'horrible']
#
# 	Topic 2:
# ['host', 'spacious', 'space', 'like', 'dirty', 'nice', 'base', 'home', 'place', 'cozy']
#
# 	Topic 3:
# ['responsive', 'host', 'helpful', 'location', 'recommend', 'convenient', 'place', 'stay', 'extremely', 'cozy']
#
# 	Topic 4:
# ['spot', 'host', 'close', 'wont', 'stay', 'room', 'place', 'apartment', 'disappointed', 'cozy']
